# %%
pip install SpeechRecognition pyttsx3 pyaudio
# Out:
# Collecting SpeechRecognitionNote: you may need to restart the kernel to use updated packages.
#
#   Downloading speechrecognition-3.14.3-py3-none-any.whl.metadata (30 kB)
# Collecting pyttsx3
#   Downloading pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Collecting pyaudio
#   Downloading PyAudio-0.2.14-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Requirement already satisfied: typing-extensions in c:\users\racha\anaconda3\lib\site-packages (from SpeechRecognition) (4.12.2)
# Collecting standard-aifc (from SpeechRecognition)
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting audioop-lts (from SpeechRecognition)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting comtypes (from pyttsx3)
#   Downloading comtypes-1.4.12-py3-none-any.whl.metadata (7.3 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Downloading pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in c:\users\racha\anaconda3\lib\site-packages (from pyttsx3) (308)
# Collecting standard-chunk (from standard-aifc->SpeechRecognition)
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Downloading speechrecognition-3.14.3-py3-none-any.whl (32.9 MB)
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#     --------------------------------------- 0.8/32.9 MB 3.3 MB/s eta 0:00:10
#    - -------------------------------------- 1.6/32.9 MB 3.8 MB/s eta 0:00:09
#    -- ------------------------------------- 2.4/32.9 MB 4.0 MB/s eta 0:00:08
#    ---- ----------------------------------- 3.4/32.9 MB 4.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 4.2/32.9 MB 4.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 4.7/32.9 MB 3.9 MB/s eta 0:00:08
#    ------ --------------------------------- 5.5/32.9 MB 3.9 MB/s eta 0:00:08
#    ------- -------------------------------- 6.6/32.9 MB 4.0 MB/s eta 0:00:07
#    -------- ------------------------------- 7.3/32.9 MB 4.0 MB/s eta 0:00:07
#    ---------- ----------------------------- 8.4/32.9 MB 4.1 MB/s eta 0:00:06
#    ----------- ---------------------------- 9.4/32.9 MB 4.1 MB/s eta 0:00:06
#    ------------ --------------------------- 10.2/32.9 MB 4.1 MB/s eta 0:00:06
#    ------------- -------------------------- 11.0/32.9 MB 4.1 MB/s eta 0:00:06
#    -------------- ------------------------- 11.5/32.9 MB 4.0 MB/s eta 0:00:06
#    -------------- ------------------------- 12.1/32.9 MB 3.9 MB/s eta 0:00:06
#    --------------- ------------------------ 12.8/32.9 MB 3.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 13.4/32.9 MB 3.8 MB/s eta 0:00:06
#    ---------------- ----------------------- 13.9/32.9 MB 3.7 MB/s eta 0:00:06
#    ----------------- ---------------------- 14.7/32.9 MB 3.7 MB/s eta 0:00:05
#    ------------------ --------------------- 15.2/32.9 MB 3.6 MB/s eta 0:00:05
#    ------------------- -------------------- 15.7/32.9 MB 3.6 MB/s eta 0:00:05
#    ------------------- -------------------- 16.3/32.9 MB 3.5 MB/s eta 0:00:05
#    -------------------- ------------------- 16.8/32.9 MB 3.5 MB/s eta 0:00:05
#    --------------------- ------------------ 17.3/32.9 MB 3.5 MB/s eta 0:00:05
#    --------------------- ------------------ 17.6/32.9 MB 3.4 MB/s eta 0:00:05
#    ---------------------- ----------------- 18.4/32.9 MB 3.4 MB/s eta 0:00:05
#    ----------------------- ---------------- 19.1/32.9 MB 3.4 MB/s eta 0:00:05
#    ------------------------ --------------- 19.9/32.9 MB 3.4 MB/s eta 0:00:04
#    ------------------------- -------------- 20.7/32.9 MB 3.4 MB/s eta 0:00:04
#    -------------------------- ------------- 21.5/32.9 MB 3.4 MB/s eta 0:00:04
#    --------------------------- ------------ 22.3/32.9 MB 3.4 MB/s eta 0:00:04
#    ---------------------------- ----------- 23.1/32.9 MB 3.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 23.9/32.9 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 24.6/32.9 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 25.4/32.9 MB 3.5 MB/s eta 0:00:03
#    ------------------------------- -------- 26.2/32.9 MB 3.5 MB/s eta 0:00:02
#    --------------------------------- ------ 27.3/32.9 MB 3.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 28.0/32.9 MB 3.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 29.1/32.9 MB 3.6 MB/s eta 0:00:02
#    ------------------------------------ --- 29.6/32.9 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 30.4/32.9 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 31.5/32.9 MB 3.6 MB/s eta 0:00:01
#    -------------------------------------- - 32.0/32.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------  32.8/32.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 32.9/32.9 MB 3.6 MB/s eta 0:00:00
# Downloading pyttsx3-2.99-py3-none-any.whl (32 kB)
# Downloading PyAudio-0.2.14-cp313-cp313-win_amd64.whl (173 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading comtypes-1.4.12-py3-none-any.whl (253 kB)
# Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Downloading standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Downloading standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Installing collected packages: standard-chunk, pyaudio, pypiwin32, comtypes, audioop-lts, standard-aifc, pyttsx3, SpeechRecognition
#
#    --------------- ------------------------ 3/8 [comtypes]
#    --------------- ------------------------ 3/8 [comtypes]
#    --------------- ------------------------ 3/8 [comtypes]
#    --------------- ------------------------ 3/8 [comtypes]
#    --------------- ------------------------ 3/8 [comtypes]
#    --------------- ------------------------ 3/8 [comtypes]
#    --------------- ------------------------ 3/8 [comtypes]
#    ------------------------------ --------- 6/8 [pyttsx3]
#    ----------------------------------- ---- 7/8 [SpeechRecognition]
#    ----------------------------------- ---- 7/8 [SpeechRecognition]
#    ----------------------------------- ---- 7/8 [SpeechRecognition]
#    ---------------------------------------- 8/8 [SpeechRecognition]
#
# Successfully installed SpeechRecognition-3.14.3 audioop-lts-0.2.2 comtypes-1.4.12 pyaudio-0.2.14 pypiwin32-223 pyttsx3-2.99 standard-aifc-3.13.0 standard-chunk-3.13.0

# %%
import speech_recognition as sr
import pyttsx3

def recognize_speech():
    recognizer = sr.Recognizer()
    engine = pyttsx3.init()

    with sr.Microphone() as source:
        print("🎤 Speak something...")
        recognizer.adjust_for_ambient_noise(source)
        try:
            audio = recognizer.listen(source, timeout=5)
            print("🔍 Processing...")
            text = recognizer.recognize_google(audio)
            print("📝 You said:", text)
            engine.say(f"You said: {text}")
            engine.runAndWait()
        except sr.UnknownValueError:
            print("❌ Could not understand audio.")
            engine.say("Sorry, I didn't catch that.")
            engine.runAndWait()
        except sr.RequestError:
            print("⚠ Could not connect to Google API.")
            engine.say("There was a connection error.")
            engine.runAndWait()
        except sr.WaitTimeoutError:
            print("⏱ Listening timed out.")
            engine.say("You didn't say anything.")
            engine.runAndWait()

# Run the function
recognize_speech()
# Out:
# 🎤 Speak something...
# 🔍 Processing...
# 📝 You said: hello
